# %%
frndz = {'Harika', 'Sathwik', 'Jashwanth', 'Sai varshini', 'Hari prasad', 'Meghana'}

# %%
frndz
# Out:
# {'Hari prasad', 'Harika', 'Jashwanth', 'Meghana', 'Sai varshini', 'Sathwik'}

# %%
frndz.add('Lahari')

# %%
frndz
# Out:
# {'Hari prasad',
#  'Harika',
#  'Jashwanth',
#  'Lahari',
#  'Meghana',
#  'Sai varshini',
#  'Sathwik'}

# %%
frndz.remove('Jashwanth')

# %%
frndz
# Out:
# {'Hari prasad', 'Harika', 'Lahari', 'Meghana', 'Sai varshini', 'Sathwik'}

# %%
frndz.discard('Hari prasad')

# %%
frndz
# Out:
# {'Harika', 'Lahari', 'Meghana', 'Sai varshini', 'Sathwik'}

# %%
frndz.pop()
# Out:
# 'Harika'

# %%
frndz.clear()

# %%
frndz
# Out:
# set()

# %%
A = {4, 5, 6, 7}
B = {6, 7, 8, 9}
A.union(B)
# Out:
# {4, 5, 6, 7, 8, 9}

# %%
C = {'Vijay kumar', 'Sai laxmi', 'Bhavana', 'Meghana', 'Sanjana'}
D = {'Thimma reddy', 'Venkat reddy', 'Sathwik', 'Vaishnavi'}
C.union(D)
# Out:
# {'Bhavana',
#  'Meghana',
#  'Sai laxmi',
#  'Sanjana',
#  'Sathwik',
#  'Thimma reddy',
#  'Vaishnavi',
#  'Venkat reddy',
#  'Vijay kumar'}

# %%
E = {'Ratnam', 'Suvarna', 'Chakravarti', 'Harika'}
F = {'Pentaiah', 'Sumitra',  'Lahari', 'Raghavendar'}
E.union(F)
# Out:
# {'Chakravarti',
#  'Harika',
#  'Lahari',
#  'Pentaiah',
#  'Raghavendar',
#  'Ratnam',
#  'Sumitra',
#  'Suvarna'}

# %%
G = {'Jangaiah', 'sadguna', 'maahi', 'Kavya', 'Karthik'}
H = {'Veerappa', 'vanaja', 'Bhavani', 'upendra', 'jalaja'}
I = {'Krishna', 'Sunitha', 'Kalyani'}
G.union(H,I)
# Out:
# {'Bhavani',
#  'Jangaiah',
#  'Kalyani',
#  'Karthik',
#  'Kavya',
#  'Krishna',
#  'Sunitha',
#  'Veerappa',
#  'jalaja',
#  'maahi',
#  'sadguna',
#  'upendra',
#  'vanaja'}

# %%
C = {'Vijay kumar', 'Sai laxmi', 'Bhavana', 'Meghana', 'Sanjana'}
D = {'Thimma reddy', 'Venkat reddy', 'Sathwik', 'Vaishnavi'}
E = {'Ratnam', 'Suvarna', 'Chakravarti', 'Harika'}
F = {'Pentaiah', 'Sumitra',  'Lahari', 'Raghavendar'}
G = {'Jangaiah', 'sadguna', 'maahi', 'Kavya', 'Karthik'}
H = {'Veerappa', 'vanaja', 'Bhavani', 'upendra', 'jalaja'}
I = {'Krishna', 'Sunitha', 'Kalyani'}
C.union(D,E,F,G,H,I)
# Out:
# {'Bhavana',
#  'Bhavani',
#  'Chakravarti',
#  'Harika',
#  'Jangaiah',
#  'Kalyani',
#  'Karthik',
#  'Kavya',
#  'Krishna',
#  'Lahari',
#  'Meghana',
#  'Pentaiah',
#  'Raghavendar',
#  'Ratnam',
#  'Sai laxmi',
#  'Sanjana',
#  'Sathwik',
#  'Sumitra',
#  'Sunitha',
#  'Suvarna',
#  'Thimma reddy',
#  'Vaishnavi',
#  'Veerappa',
#  'Venkat reddy',
#  'Vijay kumar',
#  'jalaja',
#  'maahi',
#  'sadguna',
#  'upendra',
#  'vanaja'}
